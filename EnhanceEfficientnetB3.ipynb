# %% [markdown]
# <a href="https://colab.research.google.com/github/shrybhrdwj/Brain_Tumor/blob/main/EnhanceEfficientnetB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

shrybhrdwj_brainmriimage54_path = kagglehub.dataset_download('shrybhrdwj/brainmriimage54')

print('Data source import complete.')

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers.schedules import CosineDecay
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Dataset Path
dataset_path = '/kaggle/input/brainmriimage54'
training_dir = os.path.join(dataset_path, 'Training')
testing_dir = os.path.join(dataset_path, 'Testing')

# Step 2: Image Size and Batch
image_size = (300, 300)
batch_size = 32

# Step 3: Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    shear_range=0.2,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    training_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    testing_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Step 4: Class Weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))

# Step 5: Model Definition
base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
for layer in base_model.layers[:200]:
    layer.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.4),
    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(train_generator.num_classes, activation='softmax')
])

# Step 6: Learning Rate Strategy
initial_lr = 1e-3
lr_schedule = CosineDecay(initial_learning_rate=initial_lr, decay_steps=1000)

model.compile(
    optimizer=Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# Step 7: Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]

# Step 8: Train
model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=25,
    class_weight=class_weights_dict,
    callbacks=callbacks
)

# Step 9: Fine-Tune All Layers
for layer in model.layers:
    layer.trainable = True

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy']
)

model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=10,
    class_weight=class_weights_dict,
    callbacks=callbacks
)

# Step 10: Save the Model
model.save("brain_tumor_classifier_efficientnetB3.h5")

# Step 11: Evaluation
test_generator.reset()
preds = model.predict(test_generator)
y_pred = np.argmax(preds, axis=1)
y_true = test_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# ROC Curve
lb = LabelBinarizer()
y_true_bin = lb.fit_transform(y_true)
plt.figure(figsize=(10, 8))
for i, class_name in enumerate(test_generator.class_indices.keys()):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], preds[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('AUC-ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2025-06-22 05:48:54.372987: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750571334.553586      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750571334.609601      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.
# I0000 00:00:1750571351.879290      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750571351.879948      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750571410.487616     115 service.cc:148] XLA service 0x78b9b8006490 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750571410.488471     115 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750571410.488494     115 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750571416.072763     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1750571427.414842     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571427.571460     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571428.108435     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571428.254955     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571428.603330     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571428.749546     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571429.296456     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571429.465036     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1750571448.554117     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  50/179 ━━━━━━━━━━━━━━━━━━━━ 1:46 826ms/step - accuracy: 0.3659 - loss: 1.9837
# E0000 00:00:1750571502.233920     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571502.378215     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571502.903388     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750571503.049589     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 302s 1s/step - accuracy: 0.4115 - loss: 1.8407 - val_accuracy: 0.3631 - val_loss: 1.4715 - learning_rate: 9.2300e-04
# Epoch 2/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 123s 686ms/step - accuracy: 0.5008 - loss: 1.7698 - val_accuracy: 0.4371 - val_loss: 93.7589 - learning_rate: 7.1573e-04
# Epoch 3/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 127s 710ms/step - accuracy: 0.5674 - loss: 1.3773 - val_accuracy: 0.5843 - val_loss: 1.6408 - learning_rate: 4.4201e-04
# Epoch 4/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 127s 709ms/step - accuracy: 0.6203 - loss: 1.2197 - val_accuracy: 0.6880 - val_loss: 1.0325 - learning_rate: 1.8615e-04
# Epoch 5/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 126s 706ms/step - accuracy: 0.6838 - loss: 1.1016 - val_accuracy: 0.7025 - val_loss: 1.5810 - learning_rate: 2.6957e-05
# Epoch 6/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 123s 689ms/step - accuracy: 0.6990 - loss: 1.0278 - val_accuracy: 0.7208 - val_loss: 1.6764 - learning_rate: 0.0000e+00
# Epoch 7/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 124s 694ms/step - accuracy: 0.6958 - loss: 1.0340 - val_accuracy: 0.7292 - val_loss: 1.4317 - learning_rate: 0.0000e+00
# Epoch 8/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 127s 711ms/step - accuracy: 0.7130 - loss: 1.0300 - val_accuracy: 0.7307 - val_loss: 1.6408 - learning_rate: 0.0000e+00
# Epoch 9/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 125s 695ms/step - accuracy: 0.7077 - loss: 0.9974 - val_accuracy: 0.7254 - val_loss: 1.5920 - learning_rate: 0.0000e+00
# Epoch 10/25
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 123s 689ms/step - accuracy: 0.6984 - loss: 1.0059 - val_accuracy: 0.7300 - val_loss: 1.5368 - learning_rate: 0.0000e+00
# Epoch 1/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 245s 903ms/step - accuracy: 0.6816 - loss: 0.9517 - val_accuracy: 0.6934 - val_loss: 1.1295 - learning_rate: 1.0000e-05
# Epoch 2/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 128s 711ms/step - accuracy: 0.6904 - loss: 0.9603 - val_accuracy: 0.7269 - val_loss: 1.3151 - learning_rate: 1.0000e-05
# Epoch 3/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 127s 706ms/step - accuracy: 0.6904 - loss: 0.9441 - val_accuracy: 0.7307 - val_loss: 1.3956 - learning_rate: 1.0000e-05
# Epoch 4/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 126s 705ms/step - accuracy: 0.7047 - loss: 0.8933 - val_accuracy: 0.7361 - val_loss: 1.3399 - learning_rate: 1.0000e-05
# Epoch 5/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 127s 708ms/step - accuracy: 0.7115 - loss: 0.8704 - val_accuracy: 0.7376 - val_loss: 1.3511 - learning_rate: 5.0000e-06
# Epoch 6/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 124s 694ms/step - accuracy: 0.7026 - loss: 0.8807 - val_accuracy: 0.7323 - val_loss: 1.2628 - learning_rate: 5.0000e-06
# Epoch 7/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 122s 681ms/step - accuracy: 0.7098 - loss: 0.8866 - val_accuracy: 0.7399 - val_loss: 1.3698 - learning_rate: 5.0000e-06
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.86      0.51      0.64       300
#   meningioma       0.60      0.41      0.49       306
#      notumor       0.83      0.84      0.83       405
#    pituitary       0.57      0.97      0.72       300
#
#     accuracy                           0.69      1311
#    macro avg       0.71      0.68      0.67      1311
# weighted avg       0.72      0.69      0.68      1311
